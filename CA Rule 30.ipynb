# %% [markdown]
# # Cellular Automata Rule 30

# %%
import cellpylib as cpl

# initialize a CA with 200 cells (a random initialization is also available) 
cellular_automaton = cpl.init_simple(50)

# evolve the CA for 100 time steps, using Rule 30 as defined in NKS
cellular_automaton = cpl.evolve(cellular_automaton, timesteps=50, memoize=True, 
                                apply_rule=lambda n, c, t: cpl.nks_rule(n, 30))

# plot the resulting CA evolution
cpl.plot(cellular_automaton)

# %% [markdown]
# Setup for rule 30:
# 00011110 = 16+8+4+2 = 30
# ![rule30prizeupdate092822img2X.png](attachment:rule30prizeupdate092822img2X.png)
